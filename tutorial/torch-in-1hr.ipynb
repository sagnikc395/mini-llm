# %% [markdown]
# # following along https://sebastianraschka.com/teaching/pytorch-1h/

# %% [markdown]
# things that are covered
# 1. overview of the torch deep learning library
# 2. setting up an env and workspace for dl
# 3. tensors as a fundamental data structure for dl
# 4. mechanics of training deep neural nets
# 5. training models on GPUs
